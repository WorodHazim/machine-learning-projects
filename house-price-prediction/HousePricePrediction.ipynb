# %%
import pandas as pd

data = {
    "Size": [50, 60, 80, 100, 120, 150, 180, 200],
    "Bedrooms": [1, 2, 2, 3, 3, 4, 4, 5],
    "Age": [20, 15, 10, 8, 5, 3, 2, 1],
    "Price": [150000, 180000, 220000, 300000, 340000, 400000, 450000, 500000]
}

df = pd.DataFrame(data)
df
# Out:
#    Size  Bedrooms  Age   Price
# 0    50         1   20  150000
# 1    60         2   15  180000
# 2    80         2   10  220000
# 3   100         3    8  300000
# 4   120         3    5  340000
# 5   150         4    3  400000
# 6   180         4    2  450000
# 7   200         5    1  500000

# %%
features = df[["Size", "Bedrooms", "Age"]]
target = df["Price"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    features,
    target,
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

print(predictions)
# Out:
# [198364.65210767 403417.97866938]

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, predictions)

print("MSE:", mse)
# Out:
# MSE: 174471512.61000627

# %%
model.predict([[120, 3, 5]])
# Out:
# /Users/worodhazem/ai-learning/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([412972.05925803])

# %%
df.describe()
# Out:
#              Size   Bedrooms        Age          Price
# count  100.000000  100.00000  100.00000     100.000000
# mean   170.020000    2.99000   15.06000  553164.410000
# std     71.635015    1.47364    9.23522  221165.466302
# min     51.000000    1.00000    0.00000  163974.000000
# 25%    106.250000    1.75000    6.00000  367171.000000
# 50%    163.000000    3.00000   16.00000  538485.500000
# 75%    237.000000    4.00000   23.00000  756575.250000
# max    299.000000    5.00000   29.00000  957589.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df)
plt.show()

# %%
features = df[["Size", "Bedrooms", "Age"]]

target = df["Price"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    features,
    target,
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, predictions)

print("MSE:", mse)
# Out:
# MSE: 146026592.35537463

# %%
model.predict(pd.DataFrame([[150,3,10]], columns=["Size","Bedrooms","Age"]))
# Out:
# array([498260.69868978])
